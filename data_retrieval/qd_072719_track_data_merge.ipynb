# %%
import pandas as pd

# %%
primary = pd.read_csv("../data/raw/raw_dropped_duplicates.zip")

# %%
tracks_data = pd.read_csv("../data/api_calls/tracks_data_full.zip")

# %%
primary.merge(tracks_data, on="ID", how="left").to_csv("../data/interum/track_data.csv", index=False)

# %% [markdown]
# Check data

# %%
pd.read_csv("../data/interum/track_data.zip").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107973 entries, 0 to 107972
# Data columns (total 24 columns):
# Name                      107972 non-null object
# Danceability              107973 non-null float64
# Energy                    107973 non-null float64
# Key                       107973 non-null float64
# Loudness                  107973 non-null float64
# Mode                      107973 non-null float64
# Speechness                107973 non-null float64
# Acousticness              107973 non-null float64
# Instrumentalness          107973 non-null float64
# Liveness                  107973 non-null float64
# Valence                   107973 non-null float64
# Tempo                     107973 non-null float64
# Type                      107973 non-null object
# ID                        107973 non-null object
# Uri                       107973 non-null object
# Ref_Track                 107973 non-null object
# URL_features              107973 non-null object
# Duration_ms               107973 non-null float64
# time_signature            107973 non-null float64
# Genre                     107973 non-null object
# artist_names              107973 non-null object
# artist_ids                107973 non-null object
# release_date              107973 non-null object
# release_date_precision    107973 non-null object
# dtypes: float64(13), object(11)
# memory usage: 19.8+ MB

# %%
df = pd.read_csv("../data/interum/track_data.csv")

# %%
df.head()
# Out:
#            Name  Danceability  Energy   Key  Loudness  Mode  Speechness  \
# 0    YuveYuveYu         0.624   0.857  10.0    -6.250   0.0      0.0542
# 1   Gloryhammer         0.517   0.916   0.0    -4.933   1.0      0.0559
# 2        Nostos         0.251   0.894   8.0    -4.103   0.0      0.0570
# 3     Yggdrasil         0.469   0.743   1.0    -5.570   0.0      0.0272
# 4  Incense&Iron         0.487   0.952   1.0    -4.429   0.0      0.0613
#
#    Acousticness  Instrumentalness  Liveness  ...  \
# 0      0.020800          0.206000     0.110  ...
# 1      0.000182          0.001910     0.306  ...
# 2      0.014400          0.000000     0.123  ...
# 3      0.002220          0.000111     0.276  ...
# 4      0.000228          0.000000     0.161  ...
#
#                                     Uri  \
# 0  spotify:track:6J2VvzKwWc2f0JP5RQVZjq
# 1  spotify:track:4HA34COgxgVJ6zK88UN4Ik
# 2  spotify:track:3W6Xik6Xxf06JuUoZSATlD
# 3  spotify:track:2gGveBaLJQMtJ43X4UL5kH
# 4  spotify:track:1lRF81A1C9QoCgBcEop2zg
#
#                                            Ref_Track  \
# 0  https://api.spotify.com/v1/tracks/6J2VvzKwWc2f...
# 1  https://api.spotify.com/v1/tracks/4HA34COgxgVJ...
# 2  https://api.spotify.com/v1/tracks/3W6Xik6Xxf06...
# 3  https://api.spotify.com/v1/tracks/2gGveBaLJQMt...
# 4  https://api.spotify.com/v1/tracks/1lRF81A1C9Qo...
#
#                                         URL_features Duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/6J2V...    282920.0
# 1  https://api.spotify.com/v1/audio-analysis/4HA3...    300320.0
# 2  https://api.spotify.com/v1/audio-analysis/3W6X...    175353.0
# 3  https://api.spotify.com/v1/audio-analysis/2gGv...    272292.0
# 4  https://api.spotify.com/v1/audio-analysis/1lRF...    237933.0
#
#   time_signature        Genre           artist_names  \
# 0            4.0  celticmetal                 The HU
# 1            4.0  celticmetal            Gloryhammer
# 2            4.0  celticmetal  Orion's Reign,Minniva
# 3            4.0  celticmetal      Brothers of Metal
# 4            4.0  celticmetal              Powerwolf
#
#                                       artist_ids  release_date  \
# 0                         0b2B3PwcYzQAhuJacmcYgc    2018-10-14
# 1                         7dkEByOe0oHqc54qU4hwzV    2019-04-12
# 2  3hRL14TJtJqr7i1IH3D1pU,50KIyycosYOGrBHfLaI1Ju    2018-10-05
# 3                         0WPCPYm5IDNtQjuJOGNPcy    2018-11-09
# 4                         5HFkc3t0HYETL4JeEbDB1v    2018-07-13
#
#   release_date_precision
# 0                    day
# 1                    day
# 2                    day
# 3                    day
# 4                    day
#
# [5 rows x 24 columns]

# %%
df.groupby(['release_date']).size()
# Out:
# release_date
# 0000           10
# 0001-01-01      1
# 1886            1
# 1899-12-31      3
# 1905-06-10     18
# 1928            1
# 1930            1
# 1933            1
# 1937            1
# 1938-01-01      1
# 1939            3
# 1942-01-01      1
# 1944            1
# 1946            1
# 1947            2
# 1948            2
# 1949            1
# 1950            1
# 1951-01-01      4
# 1952            1
# 1953            1
# 1954            4
# 1954-01-01      2
# 1955            1
# 1955-04-01      1
# 1955-08-09      6
# 1956            5
# 1956-01-01      1
# 1956-02-20      4
# 1956-09-10      1
#              ...
# 2019-04-05    396
# 2019-04-06     20
# 2019-04-07     10
# 2019-04-08     39
# 2019-04-09     33
# 2019-04-10     42
# 2019-04-11     42
# 2019-04-12    376
# 2019-04-13     13
# 2019-04-14      9
# 2019-04-15     40
# 2019-04-16     35
# 2019-04-17     40
# 2019-04-18     42
# 2019-04-19    217
# 2019-04-20      8
# 2019-04-21      1
# 2019-04-22     25
# 2019-04-23      5
# 2019-04-24     10
# 2019-04-25     11
# 2019-04-26     97
# 2019-04-28      1
# 2019-04-29      1
# 2019-05-01      1
# 2019-05-03      5
# 2019-05-08      1
# 2019-05-10      3
# 2019-05-17      1
# 2019-06-21      1
# Length: 7909, dtype: int64
